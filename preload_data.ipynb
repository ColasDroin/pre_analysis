# %%
import pandas as pd

# %%
# Load all the data
data_runs = pd.read_csv('data/v1/runs-data.csv')
data_games = pd.read_csv('data/v1/games-data.csv')
data_categories = pd.read_csv('data/v1/categories-data.csv')
data_leaderboards = pd.read_csv('data/v1/leaderboards-data.csv')
data_levels = pd.read_csv('data/v1/levels-data.csv')
data_users = pd.read_csv('data/v1/users-data.csv')
data_platforms = pd.read_csv('data/other_dataset_with_platforms.csv')

# %%
# Only keep the games that are per-game type
data_categories = data_categories[data_categories['type'] == 'per-game']

# %%
data_categories
# Out:
#        parentGameID        ID               name  \
# 0          j1n8nj91  8249gled  Moose's Simulator
# 1          j1n8nj91  9d8n4owd  Kevin's Simulator
# 2          j1n8nj91  vdon14vk  Original hardware
# 3          ldejl7j1  w20m70zk               Any%
# 4          9d389y91  vdopjgy2      Beat The Game
# ...             ...       ...                ...
# 147953     j1n48ll6  zdn3gpx2               Hard
# 147954     j1n48ll6  w204lxvk              Hints
# 147955     j1n48ll6  jdr0y6ld              Dies%
# 147956     j1n48ll6  wk6gleqd       Enemy Death%
# 147957     j1n48ll6  jdz4x06k         Game Over%
#
#                                                     rules      type  \
# 0       # Version\r\nMichael \"Moose\" O'Malley's simu...  per-game
# 1       # Version\r\nKevin Karstens's simulator releas...  per-game
# 2                                                     NaN  per-game
# 3       The run starts upon entering the dungeon for t...  per-game
# 4       ## Main Goal\r\n* The player must make it to t...  per-game
# ...                                                   ...       ...
# 147953                                                NaN  per-game
# 147954                                                NaN  per-game
# 147955                                                NaN  per-game
# 147956                                                NaN  per-game
# 147957                                                NaN  per-game
#
#         numPlayers
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 147953           1
# 147954           1
# 147955           1
# 147956           1
# 147957           1
#
# [119495 rows x 6 columns]

# %%
# Only keep id and plateform for data_platforms
data_platforms = data_platforms[["platform_id","platform_name"]]
# Remove duplicates
data_platforms = data_platforms.drop_duplicates()

# %%
# Merge all the datasets
data = data_runs.merge(data_games, left_on='gameID', right_on='ID', how='left', suffixes=('', '_game'))
data = data.merge(data_categories, left_on='categoryID', right_on='ID', how='left', suffixes=('', '_category'))
data = data.merge(data_levels, left_on='levelID', right_on='ID', how='left', suffixes=('', '_level'))
data = data.merge(data_users, left_on='players', right_on='ID', how='left', suffixes=('', '_user'))
data = data.merge(data_leaderboards, left_on='ID', right_on='runID', how='left', suffixes=('', '_leaderboard'))
data = data.merge(data_platforms, left_on='platform', right_on='platform_id', how='left', suffixes=('', '_plateform'))

# %%
# Delete the arrays to free up memory
del data_runs
del data_games
del data_categories
del data_leaderboards
del data_levels
del data_users
del data_platforms

# %%
# Only keep verified runs
data = data[data['status'] == 'verified']

# %%
# Delete all columns if _id or ID in the name
data = data[[col for col in data.columns if '_id' not in col and 'ID' not in col]] 

# Remove the rows with NaN values in the 'type' column (we don't want per-level data)
data = data.dropna(subset=['type', 'location'])

# %%
# Delete the other columns that are not needed
data = data.drop(
    columns=[
        "platform",
        "players",
        "examiner",
        "values",
        "status",
        "statusReason",
        "verifiedDate",
        "URL",
        "createdDate",
        "numCategories",
        "numLevels",
        "rules",
        "type",
        "numPlayers",
        "name_level",
        "rules_level",
        "signupDate",
        "platform_leaderboard",
        "emulated_leaderboard",
        "players_leaderboard",
        "examiner_leaderboard",
        "verifiedDate_leaderboard",
        "variablesAndValues",
        "date_leaderboard",
        "primaryTime_leaderboard",
        "place",
        "numRuns",
    ]
)

# %%
# Drop the rows with NaN values
data = data.dropna()

# %%
print(len(data))
data.head()
# Out:
# 1821316
#           date  primaryTime  emulated                            name  \
# 8   2021-12-22      449.533     False                          RE:RUN
# 9   2019-02-09      194.000     False                    Time Warpers
# 11  2014-11-17      857.000      True              Kirby's Dream Land
# 12  2014-11-17     3062.000     False  Kirby: Nightmare in Dream Land
# 13  2014-11-17     2454.000     False      Kirby & The Amazing Mirror
#
#    releaseDate name_category      name_user location     platform_name
# 8   2020-08-08          Any%    quebecpower    ca/qc                PC
# 9   2018-11-02   Zones 1-100           _zuR       br                PC
# 11  1992-04-27   Normal Mode  SapphireYoshi       us          Game Boy
# 12  2002-10-25          Any%  SapphireYoshi       us  Game Boy Advance
# 13  2004-04-15          Any%  SapphireYoshi       us  Game Boy Advance

# %%
# Write the data to feather
data.to_feather('data/temp/data.feather')
